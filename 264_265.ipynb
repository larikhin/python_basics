# %%
! ffprobe newsky.mp4
# Out:
# ffprobe version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2007-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
# перенесение moov в начало
#! ffmpeg -i input.mp4 -movflags faststart -c copy repaired.mp4
#Принудительное декодирование
#! ffmpeg -err_detect ignore_err -i repaired.mp4 -c copy repaired1.mp4
# Создание нового контейнера
! ffmpeg -i input.mp4 -c:v copy -c:a copy repaired.mp4
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
! ffmpeg -i input.mp4 -c:v libx265 -crf 28 -preset medium -c:a copy output_h265.mkv
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
# !ffmpeg -i input.mp4 -c:v libaom-av1 -b:v 2M -crf 30 -c:a copy output.mkv
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...
