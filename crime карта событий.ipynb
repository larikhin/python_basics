# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.11/dist-packages (0.20.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.11/dist-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from folium) (2.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.11/dist-packages (from folium) (2025.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (2025.7.14)

# %%
import json
import folium

# Пути к файлам
json_path = '/content/drive/MyDrive/Г/predict/crimes_spb_shooting.json'
html_output = '/content/drive/MyDrive/Г/predict/shooting_map.html'

# Загрузка данных
print("Чтение данных о стрельбе...")
with open(json_path, 'r', encoding='utf-8') as f:
    data = json.load(f)

# Проверка: есть ли данные
if not data:
    print("Нет данных для отображения на карте.")
else:
    print(f"Найдено {len(data)} событий со 'стрельбой'.")

    # Начальная точка карты — центр Санкт-Петербурга
    map_center = [59.9343, 30.3351]  # СПб
    m = folium.Map(location=map_center, zoom_start=11, tiles='OpenStreetMap')

    valid_markers = 0  # Счётчик добавленных меток

    # Добавление меток
    for record in data:
        lat = record.get('Широта')
        lon = record.get('Долгота')
        address = record.get('Адрес', 'Адрес не указан')
        cause = record.get('Причина', 'Причина не указана')
        date = record.get('Дата регистрации', 'Дата не указана')
        time = record.get('Время регистрации', 'Время не указано')

        # Проверка: существуют ли координаты и являются ли они числами
        if lat is None or lon is None:
            print(f"Пропущено: отсутствуют координаты — {address}")
            continue

        try:
            lat = float(lat)
            lon = float(lon)
        except (ValueError, TypeError):
            print(f"Пропущено: некорректные координаты — {address} (Широта: {lat}, Долгота: {lon})")
            continue

        # Проверка, что координаты в разумных пределах для СПб
        if not (59.0 <= lat <= 61.0) or not (29.0 <= lon <= 31.0):
            print(f"Пропущено: координаты вне диапазона СПб — {address} ({lat}, {lon})")
            continue

        # Формируем всплывающую подсказку
        popup_text = f"""
        <b>Дата:</b> {date}<br>
        <b>Время:</b> {time}<br>
        <b>Адрес:</b> {address}<br>
        <b>Причина:</b> {cause}<br>
        <b>Координаты:</b> {lat:.5f}, {lon:.5f}
        """

        # Добавляем метку на карту
        folium.CircleMarker(
            location=[lat, lon],
            radius=9,
            color='red',
            fill=True,
            fill_color='red',
            fill_opacity=0.8,
            popup=folium.Popup(popup_text, max_width=300),
            tooltip=address
        ).add_to(m)

        valid_markers += 1

    print(f"Добавлено меток на карту: {valid_markers}")

    # Сохранение карты
    m.save(html_output)
    print(f"Карта сохранена: {html_output}")
    print("Откройте файл в браузере, чтобы увидеть результат.")

    m
# Out:
# Чтение данных о стрельбе...
# Найдено 2128 событий со 'стрельбой'.
# Пропущено: координаты вне диапазона СПб — Ленинградская обл., , (nan, nan)
# Пропущено: координаты вне диапазона СПб — Ленинградская обл., , (nan, nan)
# Пропущено: координаты вне диапазона СПб — Народная улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — Парашютная улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — КАД внешнее кольцо (nan, nan)
# Пропущено: координаты вне диапазона СПб — проспект Славы (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Чекистов (nan, nan)
# Пропущено: координаты вне диапазона СПб — Ленинградская обл., , (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Доблести, дом 27 (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Маршала Казакова (nan, nan)
# Пропущено: координаты вне диапазона СПб — Ленинградская обл., , (nan, nan)
# Пропущено: координаты вне диапазона СПб — , (nan, nan)
# Пропущено: координаты вне диапазона СПб — Ленинградская обл., ,, дом 11 (nan, nan)
# Пропущено: координаты вне диапазона СПб — пос. Парголово, Осиновая Роща, Выборгское шоссе (nan, nan)
# Пропущено: координаты вне диапазона СПб — Ленинградская обл., ,, дом 11/6 (nan, nan)
# Пропущено: координаты вне диапазона СПб — Кондратьевский проспект (nan, nan)
# Пропущено: координаты вне диапазона СПб — проспект Металлистов (nan, nan)
# Пропущено: координаты вне диапазона СПб — проспект Металлистов (nan, nan)
# Пропущено: координаты вне диапазона СПб — Кондратьевский проспект (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Павловск, улица Обороны (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Павловск, Проектируемая улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — Ленинградская обл., , (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Маршала Казакова (nan, nan)
# Пропущено: координаты вне диапазона СПб — Эриванская улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Пушкин, Петербургское шоссе (nan, nan)
# Пропущено: координаты вне диапазона СПб — Аптекарская набережная (nan, nan)
# Пропущено: координаты вне диапазона СПб — None (nan, nan)
# Пропущено: координаты вне диапазона СПб — Пулковская улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — Ленинградская обл., , (nan, nan)
# Пропущено: координаты вне диапазона СПб — Выборгское шоссе (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Гастелло (nan, nan)
# Пропущено: координаты вне диапазона СПб — пос. Понтонный, улица Варвары Петровой (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Ткачей (nan, nan)
# Пропущено: координаты вне диапазона СПб — Шкиперский проток (nan, nan)
# Пропущено: координаты вне диапазона СПб — Шкиперский проток (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Седова (nan, nan)
# Пропущено: координаты вне диапазона СПб — Пушкинская улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — Великолукская улица, дом 1 (nan, nan)
# Пропущено: координаты вне диапазона СПб — пос. Стрельна, Орловский парк, (nan, nan)
# Пропущено: координаты вне диапазона СПб — пос. Шушары, Петербургское шоссе, дом 75 (nan, nan)
# Пропущено: координаты вне диапазона СПб — Шуваловский проспект (nan, nan)
# Пропущено: координаты вне диапазона СПб — Долгоозёрная улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Павловск, тер. Снт Текстиль, (nan, nan)
# Пропущено: координаты вне диапазона СПб — набережная Мартынова (nan, nan)
# Пропущено: координаты вне диапазона СПб — пос. Металлострой,, дом 47 (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Красное Село, проспект Ленина (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Коммуны (nan, nan)
# Пропущено: координаты вне диапазона СПб — парк Авиаторов, (nan, nan)
# Пропущено: координаты вне диапазона СПб — Бухарестская улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — Петергофское шоссе, дом 96 (nan, nan)
# Пропущено: координаты вне диапазона СПб — КАД внешнее кольцо (nan, nan)
# Пропущено: координаты вне диапазона СПб — Малоохтинская набережная (nan, nan)
# Пропущено: координаты вне диапазона СПб — пос. Сапёрный, Дорожная улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — None (nan, nan)
# Пропущено: координаты вне диапазона СПб — None (nan, nan)
# Пропущено: координаты вне диапазона СПб — "Нева" Москва - Санкт-Петербург (nan, nan)
# Пропущено: координаты вне диапазона СПб — Удельный парк, (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Савушкина (nan, nan)
# Пропущено: координаты вне диапазона СПб — Маркитантский переулок (nan, nan)
# Пропущено: координаты вне диапазона СПб — Стародеревенская улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — проспект Непокорённых (nan, nan)
# Пропущено: координаты вне диапазона СПб — Светлановская площадь (nan, nan)
# Пропущено: координаты вне диапазона СПб — пос. Петро-Славянка, ВСМ, (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Колпино, улица Ижорского Батальона, дом 3, корпус 2 (nan, nan)
# Пропущено: координаты вне диапазона СПб — Новочеркасский проспект (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Пушкин, Рехколовское шоссе (nan, nan)
# Пропущено: координаты вне диапазона СПб — муниципальный округ Звездное, Среднерогатская улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Красное Село, улица Первого Мая (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Пограничника Гарькавого (nan, nan)
# Пропущено: координаты вне диапазона СПб — Дальневосточный проспект (nan, nan)
# Пропущено: координаты вне диапазона СПб — , (nan, nan)
# Пропущено: координаты вне диапазона СПб — Институтский проспект (nan, nan)
# Пропущено: координаты вне диапазона СПб — КАД внешнее кольцо (nan, nan)
# Пропущено: координаты вне диапазона СПб — 2-й Муринский проспект (nan, nan)
# Пропущено: координаты вне диапазона СПб — 2-й Муринский проспект (nan, nan)
# Пропущено: координаты вне диапазона СПб — проспект Космонавтов (nan, nan)
# Пропущено: координаты вне диапазона СПб — Боровая улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Павловск, тер. Снт Павловское-1, (nan, nan)
# Пропущено: координаты вне диапазона СПб — ,, дом 4 (nan, nan)
# Пропущено: координаты вне диапазона СПб — дорога на Турухтанные Острова (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Колпино, Пролетарская улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — Литейный проспект (nan, nan)
# Пропущено: координаты вне диапазона СПб — Яхтенная улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Коллонтай (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Коллонтай, дом 18 (nan, nan)
# Пропущено: координаты вне диапазона СПб — КАД внешнее кольцо (nan, nan)
# Пропущено: координаты вне диапазона СПб — None (nan, nan)
# Пропущено: координаты вне диапазона СПб — площадь Победы (nan, nan)
# Пропущено: координаты вне диапазона СПб — Апраксин переулок (nan, nan)
# Пропущено: координаты вне диапазона СПб — Кубанская улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — дорога в Каменку (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Коллонтай (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Коллонтай (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Зины Портновой (nan, nan)
# Пропущено: координаты вне диапазона СПб — КАД внешнее кольцо (nan, nan)
# Пропущено: координаты вне диапазона СПб — парк Сосновка, (nan, nan)
# Пропущено: координаты вне диапазона СПб — парк Сосновка, (nan, nan)
# Пропущено: координаты вне диапазона СПб — Ленинградская обл., Всеволожский р-н,, дом 34 (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Сестрорецк, сад-во "Разлив", (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Пушкин, бульвар Алексея Толстого (nan, nan)
# Пропущено: координаты вне диапазона СПб — , (nan, nan)
# Пропущено: координаты вне диапазона СПб — Малоохтинский проспект (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Коллонтай (nan, nan)
# Пропущено: координаты вне диапазона СПб — проспект Большевиков (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Кустодиева, дом 9, кв. 49 (nan, nan)
# Пропущено: координаты вне диапазона СПб — КАД внутреннее кольцо (nan, nan)
# Пропущено: координаты вне диапазона СПб — КАД внутреннее кольцо (nan, nan)
# Пропущено: координаты вне диапазона СПб — Лужская улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Ушинского (nan, nan)
# Пропущено: координаты вне диапазона СПб — Лиственная улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Черкасова (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Петергоф, Привокзальная площадь, дом 29 (nan, nan)
# Пропущено: координаты вне диапазона СПб — Приморское шоссе (nan, nan)
# Пропущено: координаты вне диапазона СПб — набережная канала Грибоедова, дом 60 (nan, nan)
# Пропущено: координаты вне диапазона СПб — Будапештская улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Черняховского (nan, nan)
# Пропущено: координаты вне диапазона СПб — Думская улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — Парашютная улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — пос. Песочный, Белоостровское шоссе (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Сантьяго-де-Куба (nan, nan)
# Пропущено: координаты вне диапазона СПб — 4-й Верхний переулок (nan, nan)
# Пропущено: координаты вне диапазона СПб — проспект Героев (nan, nan)
# Пропущено: координаты вне диапазона СПб — Краснопутиловская улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — Дворцовая площадь (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Хошимина (nan, nan)
# Пропущено: координаты вне диапазона СПб — проспект Наставников (nan, nan)
# Пропущено: координаты вне диапазона СПб — Приморское шоссе (nan, nan)
# Пропущено: координаты вне диапазона СПб — Крюкова улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — набережная реки Мойки, дом 99 (nan, nan)
# Пропущено: координаты вне диапазона СПб — Горелово, (nan, nan)
# Пропущено: координаты вне диапазона СПб — проспект Энтузиастов (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Пушкин, улица Архитектора Данини, дом 10 (nan, nan)
# Пропущено: координаты вне диапазона СПб — Вербная улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — Байконурская улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Колпино, Тверская улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — пос. Лисий Нос, (nan, nan)
# Пропущено: координаты вне диапазона СПб — Берёзовая аллея (nan, nan)
# Пропущено: координаты вне диапазона СПб — муниципальный округ Горелово, тер. Снт Красный треугольник, (nan, nan)
# Пропущено: координаты вне диапазона СПб — , (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Жака Дюкло (nan, nan)
# Пропущено: координаты вне диапазона СПб — площадь Трезини (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Колпино, Октябрьская улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Колпино, Загородная улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — КАД внутреннее кольцо (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Пушкин, Церковная улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — муниципальный округ Южно-Приморский, Балтийский бульвар (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Адмирала Черокова (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Адмирала Черокова (nan, nan)
# Пропущено: координаты вне диапазона СПб — пос. Репино, Большой проспект, дом 312 (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Оптиков (nan, nan)
# Пропущено: координаты вне диапазона СПб — Г.СМОЛЕНСК УЛ.ЛАВОЧКИНА , дом 41, кв. 89 (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Ломоносов, Михайловская улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Типанова (nan, nan)
# Пропущено: координаты вне диапазона СПб — бульвар Красных Зорь (nan, nan)
# Пропущено: координаты вне диапазона СПб — проспект Шаумяна (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Черняховского (nan, nan)
# Пропущено: координаты вне диапазона СПб — 15-я линия В.О. (nan, nan)
# Пропущено: координаты вне диапазона СПб — Кубинская улица, дом 2 (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Чапыгина, дом 1 (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Колпино, Колпинский парк, (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Крыленко (nan, nan)
# Пропущено: координаты вне диапазона СПб — пос. Петро-Славянка, (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Красное Село, Стрельнинское шоссе (nan, nan)
# Пропущено: координаты вне диапазона СПб — Лесной проспект (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Красное Село, Пушкинское шоссе (nan, nan)
# Пропущено: координаты вне диапазона СПб — Петергофское шоссе (nan, nan)
# Пропущено: координаты вне диапазона СПб — пос. Шушары, Школьная улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Колпино, Красная улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Колпино, Вознесенское шоссе (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Кронштадт, Якорная площадь (nan, nan)
# Пропущено: координаты вне диапазона СПб — Коломяжский проспект (nan, nan)
# Пропущено: координаты вне диапазона СПб — Коломяжский проспект (nan, nan)
# Пропущено: координаты вне диапазона СПб — площадь Тургенева (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Есенина (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Колпино, о. Чухонка, (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Зеленогорск, территория Красавица, (nan, nan)
# Пропущено: координаты вне диапазона СПб — Большая Пушкарская улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — проспект Славы (nan, nan)
# Пропущено: координаты вне диапазона СПб — Коломяжский проспект (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Сестрорецк, Приморское шоссе (nan, nan)
# Пропущено: координаты вне диапазона СПб — , (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Академика Харитона (nan, nan)
# Пропущено: координаты вне диапазона СПб — Мебельная улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Антонова-Овсеенко (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Ольги Форш (nan, nan)
# Пропущено: координаты вне диапазона СПб — КАД внутреннее кольцо (nan, nan)
# Пропущено: координаты вне диапазона СПб — Кронверкский проспект (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Пушкин, Петербургское шоссе (nan, nan)
# Пропущено: координаты вне диапазона СПб — None (nan, nan)
# Пропущено: координаты вне диапазона СПб — 7-я Советская улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Ленсовета (nan, nan)
# Пропущено: координаты вне диапазона СПб — муниципальный округ Коломяги, территория Большая Каменка, (nan, nan)
# Пропущено: координаты вне диапазона СПб — муниципальный округ Полюстрово, Васнецовский проспект (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Пушкин, Киевское шоссе (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Кронштадт, (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Зубарева (nan, nan)
# Пропущено: координаты вне диапазона СПб — пос. Парголово, тер. Снт Левашово, 19-я аллея (nan, nan)
# Пропущено: координаты вне диапазона СПб — пос. Петро-Славянка, улица Труда (nan, nan)
# Пропущено: координаты вне диапазона СПб — КАД внешнее кольцо (nan, nan)
# Пропущено: координаты вне диапазона СПб — Московский проспект (nan, nan)
# Пропущено: координаты вне диапазона СПб — Большая Пороховская улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Колпино, Балканская дорога (nan, nan)
# Пропущено: координаты вне диапазона СПб — Средний проспект В.О. (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Сестрорецк, тер. Снт Разлив, (nan, nan)
# Пропущено: координаты вне диапазона СПб — пос. Шушары, Новгородский проспект (nan, nan)
# Пропущено: координаты вне диапазона СПб — пос. Парголово, Толубеевский проезд (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Красное Село, Пушкинское шоссе (nan, nan)
# Пропущено: координаты вне диапазона СПб — парк Сосновка, (nan, nan)
# Пропущено: координаты вне диапазона СПб — Большеохтинский мост (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Белышева, дом 9 (nan, nan)
# Пропущено: координаты вне диапазона СПб — КАД внутреннее кольцо (nan, nan)
# Пропущено: координаты вне диапазона СПб — Московский проспект (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Салова (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Бабушкина (nan, nan)
# Пропущено: координаты вне диапазона СПб — Станционный п., (nan, nan)
# Пропущено: координаты вне диапазона СПб — пос. Шушары, территория Ленсоветовский,, дом 256, корпус 4 (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Пушкин, Киевское шоссе (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Пушкин, Кондакопшино, (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Петергоф, улица Братьев Горкушенко (nan, nan)
# Пропущено: координаты вне диапазона СПб — проспект Луначарского (nan, nan)
# Пропущено: координаты вне диапазона СПб — Амурская улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Пушкин, Камероновская улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — КАД внешнее кольцо (nan, nan)
# Пропущено: координаты вне диапазона СПб — Малая Морская улица, дом 24 (nan, nan)
# Пропущено: координаты вне диапазона СПб — Парашютная улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — Петергофское шоссе, дом 96 (nan, nan)
# Пропущено: координаты вне диапазона СПб — Бестужевская улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — Бестужевская улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — парк Малиновка, (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Композиторов (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Сестрорецк, улица Токарева (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Санкт-ПетербургПерекресток: Ольховая улица, улица Маршала Новикова (nan, nan)
# Пропущено: координаты вне диапазона СПб — Суздальский проспект (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Колпино, Вознесенское шоссе (nan, nan)
# Пропущено: координаты вне диапазона СПб — Баррикадная улица, дом 27 (nan, nan)
# Пропущено: координаты вне диапазона СПб — муниципальный округ Горелово, территория Горелово, Московская улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — Митрофаньевское шоссе (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Зеленогорск, (nan, nan)
# Пропущено: координаты вне диапазона СПб — , (nan, nan)
# Пропущено: координаты вне диапазона СПб — Невский проспект (nan, nan)
# Пропущено: координаты вне диапазона СПб — Малый проспект В.О. (nan, nan)
# Пропущено: координаты вне диапазона СПб — Ленинский проспект (nan, nan)
# Пропущено: координаты вне диапазона СПб — Карельский переулок (nan, nan)
# Пропущено: координаты вне диапазона СПб — Карельский переулок, дом 4 (nan, nan)
# Пропущено: координаты вне диапазона СПб — улица Партизана Германа (nan, nan)
# Пропущено: координаты вне диапазона СПб — Кирилловская улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — Кирилловская улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — КАД внутреннее кольцо (nan, nan)
# Пропущено: координаты вне диапазона СПб — Верхняя улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — КАД внутреннее кольцо (nan, nan)
# Пропущено: координаты вне диапазона СПб — пос. Молодёжное, (nan, nan)
# Пропущено: координаты вне диапазона СПб — Индустриальный проспект (nan, nan)
# Пропущено: координаты вне диапазона СПб — Артиллерийская улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — Дворцовая набережная (nan, nan)
# Пропущено: координаты вне диапазона СПб — проспект Ветеранов (nan, nan)
# Пропущено: координаты вне диапазона СПб — парк Екатерингоф, (nan, nan)
# Пропущено: координаты вне диапазона СПб — Новороссийская улица, дом 55 (nan, nan)
# Пропущено: координаты вне диапазона СПб — проспект Ударников (nan, nan)
# Пропущено: координаты вне диапазона СПб — проспект Стачек (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Петергоф, улица Шахматова (nan, nan)
# Пропущено: координаты вне диапазона СПб — Свердловская набережная (nan, nan)
# Пропущено: координаты вне диапазона СПб — КАД внешнее кольцо (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Пушкин, Софийский бульвар (nan, nan)
# Пропущено: координаты вне диапазона СПб — Ириновский проспект (nan, nan)
# Пропущено: координаты вне диапазона СПб — тер. СНТ Строитель-2 (массив Михайловский) (nan, nan)
# Пропущено: координаты вне диапазона СПб — КАД внутреннее кольцо (nan, nan)
# Пропущено: координаты вне диапазона СПб — КАД внутреннее кольцо (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Зеленогорск, территория Решетниково, (nan, nan)
# Пропущено: координаты вне диапазона СПб — Московский проспект (nan, nan)
# Пропущено: координаты вне диапазона СПб — Торики, улица Дружбы (nan, nan)
# Пропущено: координаты вне диапазона СПб — пос. Песочный, Белоостровское шоссе (nan, nan)
# Пропущено: координаты вне диапазона СПб — пос. Солнечное, Петровская улица (nan, nan)
# Пропущено: координаты вне диапазона СПб — Рыбацкий проспект (nan, nan)
# Пропущено: координаты вне диапазона СПб — г.Ломоносов, Иликовский проспект (nan, nan)
# Добавлено меток на карту: 1854
# Карта сохранена: /content/drive/MyDrive/Г/predict/shooting_map.html
# Откройте файл в браузере, чтобы увидеть результат.
