# %%
# Шаг 1: Включаем поддержку 32-битных библиотек и устанавливаем wine32
# !dpkg --add-architecture i386 && apt update
# !apt install -y wine32

# Шаг 2: Загружаем Windows-версию Python Embed (без GUI)
# !wget https://www.python.org/ftp/python/3.10.11/python-3.10.11-embed-amd64.zip  -O python-embed.zip
# !unzip python-embed.zip -d win_python/

# Шаг 3: Подготовка Python к работе с pip
# !cp win_python/python310._pth win_python/python._pth
with open("win_python/sitecustomize.py", "w") as f:
    f.write("import sys\nsys.path.append('win_python')\n")

# Шаг 4: Скачиваем get-pip.py и устанавливаем pip
# !wget https://bootstrap.pypa.io/get-pip.py  -O get-pip.py
# !wine win_python/python.exe get-pip.py

# Шаг 5: Устанавливаем PyInstaller через pip
# !wine win_python/python.exe -m pip install PyInstaller

# Шаг 6: Создаём тестовый скрипт
with open("test.py", "w") as f:
    f.write("""
print("Привет из .exe!")
input("Нажми Enter...")
""")

# Шаг 7: Компилируем в .exe
# !wine win_python/python.exe -m PyInstaller --noconfirm --onefile --distpath ./dist test.py

# Шаг 8: Проверяем, создался ли файл
# !ls dist/

# Шаг 9: Скачиваем готовый .exe
from google.colab import files
files.download("dist/test.exe")
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 129 kB in 1s (99.8 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 86 packages can be upgraded. Run 'apt list --upgradable' to see them.
# ...
