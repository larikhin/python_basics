# %%
# !pip install pyinstaller
# !pip uninstall pathlib

# %%
# !pyinstaller --noconsole --onefile hello.py
# Out:
# 407 INFO: PyInstaller: 6.13.0, contrib hooks: 2025.4
# 407 INFO: Python: 3.11.12
# 411 INFO: Platform: Linux-6.1.123+-x86_64-with-glibc2.35
# 411 INFO: Python environment: /usr
# 411 INFO: wrote /content/hello.spec
# 414 INFO: Module search paths (PYTHONPATH):
# ['/env/python',
#  '/usr/lib/python311.zip',
#  '/usr/lib/python3.11',
#  '/usr/lib/python3.11/lib-dynload',
#  '/usr/local/lib/python3.11/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.11/dist-packages/setuptools/_vendor',
#  '/content']
# pygame 2.6.1 (SDL 2.28.4, Python 3.11.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# 1157 INFO: checking Analysis
# 1161 INFO: Building because /content/hello.py changed
# 1161 INFO: Running Analysis Analysis-00.toc
# 1161 INFO: Target bytecode optimization level: 0
# 1161 INFO: Initializing module dependency graph...
# 1161 INFO: Initializing module graph hook caches...
# ...

# %%
!  /content/dist/hello
# Out:
# Hello! я выполнился без питона!
